# %%
name=input("enter your name")
# Out:
# enter your name kholoud mamdouh

# %%
print(name)
# Out:
# kholoud mamdouh

# %%
print(f"hi {name} welcom to be")
# Out:
# hi kholoud mamdouh welcom to be

# %%
age=int(input("enter your age"))
# Out:
# enter your age 27

# %%
print(f"i have ,{age},years old")
# Out:
# i have ,27,years old

# %%
name=input("enter your name")
address=input("enter your address")
# Out:
# enter your name kholoud mamdouh
# enter your address koppry el quba

# %%
print(f"i live in ,{address},")
# Out:
# i live in ,koppry el quba,

# %%
a=12
b=13

# %%
print(a,b, sep=",")
# Out:
# 12,13

# %%
favoritecolor=input("enter your favorite color")
# Out:
# enter your favorite color black

# %%
print(f"i love ,{favoritecolor},color")
# Out:
# i love ,black,color

# %%
name=input("enter your name")
age=int(input("enter your age"))
college=input("enter your college")
# Out:
# enter your name kholoud mamdouh
# enter your age 27
# enter your college mis computers

# %%
print(name,age,college, sep=" ")
# Out:
# kholoud mamdouh 27 mis computers

# %%
a=15
a=int(input())
if a>10:
    print("a>10")
# Out:
#  15
# a>10

# %%
age=19
age=int(input())
if age>18 or age==18:
    print("you are an adult")
# Out:
#  19
# you are an adult

# %%
password="python"
password=input()
if (password=="python"):
    print("access granted")
# Out:
#  python
# access granted

# %%
studentgrade=70
studentgrade=int(input())
if (studentgrade>50) or (studentgrade==50):
    print("passed")
# Out:
#  70
# passed
