# %%
a=10
b=12
c=12.6

# %%
print(a)
print(b)
print(c)
# Out:
# 10
# 12
# 12.6

# %%
a="python programming"

# %%
print(a)
# Out:
# python programming

# %%
a=27
b=2.7
c="kholoud"

# %%
print(type(a),a)
print(type(b),b)
print(type(c),c)
# Out:
# <class 'int'> 27
# <class 'float'> 2.7
# <class 'str'> kholoud

# %%
a="data analysis"

# %%
print(len(a))
# Out:
# 13

# %%
a="python"

# %%
print(a.upper())
# Out:
# PYTHON

# %%
a="PYTHON"

# %%
print(a.lower())
# Out:
# python

# %%
a="data"
b="science"
c=a+" "+b

# %%
print(c)
# Out:
# data science

# %%
a="programming"

# %%
print(a[0])
print(a[10])
# Out:
# p
# g

# %%
a="i like java"

# %%
print(a.replace("java","python"))
# Out:
# i like python

# %%
a= " ahmed "

# %%
print(a.strip())
# Out:
# ahmed

# %%
a="python programing"

# %%
print(a[:6:1])
# Out:
# python

# %%
a="data science"

# %%
print(a[5::1])
# Out:
# science

# %%
a="python"

# %%
print(a[::-1])
# Out:
# nohtyp
