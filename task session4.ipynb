# %%
number=[1,23,15,12,6]
print(number)
# Out:
# [1, 23, 15, 12, 6]

# %%
fruits=["apple","banana","orange"]
print(fruits)
fruits.append("strubary")
print(fruits)
# Out:
# ['apple', 'banana', 'orange']
# ['apple', 'banana', 'orange', 'strubary']

# %%
colors=["black","red","blue"]
print(colors)
colors.remove("red")
print(colors)
# Out:
# ['black', 'red', 'blue']
# ['black', 'blue']

# %%
names=["kholoud","ayat","shrouk"]
print(len(names))
# Out:
# 3

# %%
numbers=(1,12,15,17)
print(numbers)
# Out:
# (1, 12, 15, 17)

# %%
days=("saterday","sunday","monday")
print(days[0])
# Out:
# saterday

# %%
numbers=[1,12,13,12]
print(numbers)
# Out:
# [1, 12, 13, 12]

# %%
numbers={1,12,13,12}
print(numbers)
# Out:
# {1, 12, 13}

# %%
numbers={1,12,13}
numbers.add(15)
print(numbers)
# Out:
# {1, 12, 13, 15}

# %%
data={"name":"kholoud",
         "age":27}
print(data)
# Out:
# {'name': 'kholoud', 'age': 27}

# %%
product={"name":"oppo",
         "price":7000}
product.get("price")
# Out:
# 7000
