# %%
a=int(input("enter a"))
b=int(input("enter b"))
# Out:
# enter a 5
# enter b 2

# %%
print(a//b)
# Out:
# 2

# %%
a=int(input("enter a"))
b=int(input("enter b"))
# Out:
# enter a 5
# enter b 2

# %%
print(a%b)
# Out:
# 1

# %%
a=int(input("enter a"))
# Out:
# enter a 6

# %%
if a%2==0:
    print("the number is even")
# Out:
# the number is even

# %%
a%2
# Out:
# 0

# %%
a=int(input("enter a"))
b=int(input("enter b"))
# Out:
# enter a 5
# enter b 2

# %%
print(a//b)
print(a%b)
# Out:
# 2
# 1

# %%
a=int(input("enter a"))
# Out:
# enter a 7

# %%
if a%3==0:
    print("divisible by 3")
elif a%5==0:
    print("divisible by 5")
else:
    print("not divisible by 3 or 5")
# Out:
# not divisible by 3 or 5

# %%
print(7%3)
print(7%5)
# Out:
# 1
# 2

# %%
a=int(input("enter a"))
# Out:
# enter a 5

# %%
if a%2==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
a=int(input("enter a"))
b=int(input("enter b"))
# Out:
# enter a 10
# enter b 5

# %%
if a==b:
    print("equal")
elif a>b:
    print("first is greater")
else:
    print("second is greater")
# Out:
# first is greater

# %%
a=int(input("enter a"))
# Out:
# enter a 20

# %%
if a<10:
    print("small")
if "a is between 10 and 50":
    print("medium")
if a>50:
    print("large")
# Out:
# medium
